# %%
# Task-1
temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5, 16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1, 
17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7, 
17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 
16.6, 12.5] 

# 1 
cold = []
mild = []
comfortable = []

#2
for temp in temperatures: 
    if temp < 10:
        cold.append(temp)
    elif 10<= temp <= 15:
        mild.append(temp)
    elif 15<= temp <= 20:
        comfortable.append(temp)
        
# 3
print("Cold: ",cold)
print("Mild: ",mild)
print("Comfortable: ",comfortable,"\n")

# Task-2 
# 1
print("Cold count = ",len(cold))
print("Mild count = ",len(mild))
print("Comfortable count = ",len(comfortable),"\n")

# Task-3
temperatures_fahrenheit = []
# 1
for temp in temperatures: 
    fahrenheit = (temp * 9/5) + 32
    # 2
    temperatures_fahrenheit.append (fahrenheit)
# 3
print("Temperatures in fahrenheit: ",temperatures_fahrenheit)
# Out:
# Cold:  [8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# Mild:  [14.1, 13.5, 13.0, 12.9, 13.3, 14.0, 13.4, 14.2, 12.8, 13.7, 13.6, 13.8, 13.9, 12.7, 13.1, 12.5]
# Comfortable:  [17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]
#
# Cold count =  16
# Mild count =  16
# Comfortable count =  16
#
# Temperature in fahrenheit:  [46.76, 63.32, 57.379999999999995, 46.22, 64.4, 56.3, 48.2, 64.04, 55.4, 47.3, 61.7, 55.22, 45.86, 62.959999999999994, 55.94, 47.120000000000005, 62.059999999999995, 57.2, 49.1, 64.94, 56.120000000000005, 46.58, 64.22, 57.56, 45.68, 62.6, 55.04, 46.4, 62.24, 56.66, 46.04, 63.5, 56.48, 47.66, 62.78, 56.84, 48.56, 64.58, 57.02, 46.94, 61.519999999999996, 54.86, 48.02, 64.75999999999999, 55.58, 46.04, 61.88, 54.5]

# %%
# Task-4 
import matplotlib.pyplot as plt
temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5, 16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1, 
17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7, 
17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 
16.6, 12.5] 

# 1
night = []
day = []
evening = []

# 2
for i, temp in enumerate(temperatures):
    if i % 24 < 8:  # Night (00-08)
        night.append(temp)
    elif i % 24 < 16:  # Evening (08-16)
        evening.append(temp)
    else:  # Day (16-24)
        day.append(temp)

# 3
day_total = 0  
day_count = 0
for temp in day:
    day_total += temp  
    day_count += 1  
 
if day_count > 0:
    average_day_temp = day_total / day_count
else:
    average_day_temp = 0

print("Night Temperatures: ", night)
print("Evening Temperatures: ", evening)
print("Day Temperatures: ", day)
print("Average Day-time Temperature: ",average_day_temp)

# 4
# 5. Plot "Day vs. Temperature"
plt.figure(figsize=(10, 6))
plt.plot(day, marker='o', linestyle='-', color='b', label="Day Temperatures")
plt.axhline(y=average_day_temp, color='r', linestyle='--', label="Average Day Temp")  # Add average line

plt.title("Day vs. Temperature", fontsize=14)
plt.xlabel("Day Time Index", fontsize=12)
plt.ylabel("Temperature (°C)", fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Night Temperatures:  [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5]
# Evening Temperatures:  [13.0, 8.5, 16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3]
# Day Temperatures:  [16.7, 14.0, 9.5, 18.3, 13.4, 8.1, 17.9, 14.2, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5]
# Average Day-time Temperature:  13.643749999999999

# %%
# Recursion 

# Task-1 
def sum_nested_list(nested_list):
    """
    Recursively sums all integers in a nested list.
    
    Args:
    nested_list (list): A list containing integers or other nested lists.
    
    Returns:
    int: The total sum of all integers in the nested list.
    """
    total = 0
    for element in nested_list:
        if isinstance(element, list):  
            total += sum_nested_list(element)  
        else:
            total += element 
    return total

# Testing the function
nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
result = sum_nested_list(nested_list)
print("Sum of nested list:", result)
# Out:
# Sum of nested list: 36

# %%
# Task-2 
def generate_permutations(s):
    """
    Generates all unique permutations of a given string.

    Args:
    s (str): Input string.

    Returns:
    list: A list of all unique permutations.
    """
    if len(s) <= 1:
        return [s]
    
    permutations = []
    for i, char in enumerate(s):
        remaining = s[:i] + s[i+1:]
        for perm in generate_permutations(remaining):
            permutations.append(char + perm)
    
    return list(set(permutations))

print(generate_permutations("abc"))
print(generate_permutations("aab"))
# Out:
# ['bca', 'cab', 'acb', 'cba', 'abc', 'bac']
# ['aba', 'aab', 'baa']

# %%
# Task-3
def calculate_directory_size(directory):
    """
    Recursively calculates the total size of a directory, including all files
    and nested subdirectories.

    Args:
    directory (dict): A dictionary where keys are file names or directory names,
                      and values are file sizes (integers in KB) or nested directories (dict).

    Returns:
    int: The total size of the directory in KB.
    """
    total_size = 0
    for item, value in directory.items():
        if isinstance(value, dict):  # 1
            total_size += calculate_directory_size(value)  # 2
        else:  # If value is a file, add its size to total
            total_size += value
    return total_size

# Sample directory structure
directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}

# Testing the function
print(calculate_directory_size(directory_structure))  # Expected output: 1900 KB
# Out:
# 1400

# %%
# Dynamic programming 
# Task-1 
def min_coins(coins, amount):
    """
    Finds the minimum number of coins needed to make up a given amount using dynamic programming.
    
    Parameters:
    coins (list of int): A list of coin denominations available for making change.
    amount (int): The target amount for which we need to find the minimum number of coins.
    
    Returns:
    int: The minimum number of coins required to make the given amount.
         If it is not possible to make the amount with the given coins, returns -1.
    
    Example:
    >>> min_coins([1, 2, 5], 11)
    3
    >>> min_coins([2], 3)
    -1
    """
    
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0  
    
    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)
    
    
    return dp[amount] if dp[amount] != float('inf') else -1

# %%
# Task-2 
# 1
def longest_common_subsequence(s1, s2):
    """
    Finds the length of the longest common subsequence (LCS) of two strings using dynamic programming.

    Parameters:
    s1 (str): First string.
    s2 (str): Second string.

    Returns:
    int: Length of the longest common subsequence.
    
    Example:
    >>> longest_common_subsequence("abcde", "ace")
    3
    """
    dp = [[0] * (len(s2) + 1) for _ in range(len(s1) + 1)]
    for i in range(1, len(s1) + 1):
        for j in range(1, len(s2) + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
                
    return dp[len(s1)][len(s2)]
# 2
print(longest_common_subsequence("abcde", "ace"))  
print(longest_common_subsequence("abc", "def"))   
print(longest_common_subsequence("blablabla", "bblb"))
# Out:
# 3
# 0
# 4

# %%
# Task-3
# 1
def knapsack(weights, values, capacity):
    """
    Solves the 0/1 Knapsack problem using dynamic programming to maximize the total value within the weight capacity.

    Parameters:
    weights (list of int): List of weights for each item.
    values (list of int): List of values for each item.
    capacity (int): The weight capacity of the knapsack.

    Returns:
    int: The maximum value that can be achieved without exceeding the weight capacity.
    
    Example:
    >>> knapsack([1, 3, 4, 5], [1, 4, 5, 7], 7)
    9
    """
    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)] 
    
    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i-1] <= w:
                dp[i][w] = max(dp[i-1][w], values[i-1] + dp[i-1][w - weights[i-1]])
            else:
                dp[i][w] = dp[i-1][w] 
    return dp[n][capacity]

# 2
weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7

print(knapsack(weights, values, capacity))
# Out:
# 9
